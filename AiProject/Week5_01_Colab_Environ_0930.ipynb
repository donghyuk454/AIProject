# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()

# %%
import platform

platform.platform()

# %%
# !cat /etc/issue.net

# %%
# !cat /proc/meminfo

# %%
# !cat /proc/cpuinfo

# %%
# !df -h

# %%
# !nvidia-smi

# %%
# !nvcc -V

# %%
# !python --version

# %%
# !ls

# %%
# !pip list
