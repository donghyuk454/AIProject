# %% [markdown]
# # Week 5 Exercise

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Transform the given image with at least 3 different methods
# Try to make it look like the below image

# %% [markdown]
# ![다운로드.png](data:image/png;base64,...)

# %%
# !wget https://i.pinimg.com/originals/21/ae/ae/21aeae8d2cae56289bd55665fb5d9b8f.jpg
# !mv 21aeae8d2cae56289bd55665fb5d9b8f.jpg example.jpg
# !rm 21aeae8d2cae56289bd55665fb5d9b8f.jpg
# Out:
# --2021-09-30 10:59:48--  https://i.pinimg.com/originals/21/ae/ae/21aeae8d2cae56289bd55665fb5d9b8f.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 151.101.36.84, 2a02:26f0:b200:38b::1931, 2a02:26f0:b200:381::1931, ...
# Connecting to i.pinimg.com (i.pinimg.com)|151.101.36.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48642 (48K) [image/jpeg]
# Saving to: ‘21aeae8d2cae56289bd55665fb5d9b8f.jpg’
#
# 21aeae8d2cae56289bd 100%[===================>]  47.50K  --.-KB/s    in 0.003s
#
# 2021-09-30 10:59:48 (13.5 MB/s) - ‘21aeae8d2cae56289bd55665fb5d9b8f.jpg’ saved [48642/48642]
#
# rm: cannot remove '21aeae8d2cae56289bd55665fb5d9b8f.jpg': No such file or directory

# %%
from PIL import Image as Img
from torchvision import transforms

im = Img.open('example.jpg')

# %%
# Write your code
transform = transforms.Resize((120, 300))
transform = transforms.ColorJitter(brightness=1, contrast=2, saturation=6, hue=0.3)

# %%
transform(im)
# Out:
# <PIL.Image.Image image mode=RGB size=490x490 at 0x7FCD4284BC50>
