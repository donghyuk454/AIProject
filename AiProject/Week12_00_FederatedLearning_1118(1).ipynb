# %%
import copy
import sys

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchvision import transforms
from torchvision.datasets import MNIST
from tqdm.notebook import tqdm

# %%
plt.rcParams['figure.figsize'] = (50, 10)

# %%
# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sys.stdout.write(f'{device}')
# Out:
# cpu

# %%
# Model
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, stride=1, padding=0)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 16, kernel_size=3, stride=2, padding=1)
        self.fc1 = nn.Linear(1152, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = x.view(-1, 1, 28, 28)
        x = F.avg_pool2d(F.relu(self.conv1(x)), 2)
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        out = self.fc2(x)
        return out

# %%
# Datasets and dataloaders
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = MNIST(root='./data', train=False, transform=transform)

batch_size = 256
trainloader = DataLoader(train_dataset, batch_size=batch_size)
testloader = DataLoader(test_dataset, batch_size=batch_size)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Train and evaluate centralized
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

train_losses_central = []
eval_losses_central = []
eval_acc_central = []

for ep in tqdm(range(20)):
    # Training
    ep_losses = []
    model.train()
    for xs, ys in trainloader:
        xs, ys = xs.to(device), ys.to(device)
        model.zero_grad()
        outputs = model(xs)
        loss = criterion(outputs, ys)
        loss.backward()
        optimizer.step()
        ep_losses.append(loss.item())
    ep_loss_avg = sum(ep_losses) / len(ep_losses)
    train_losses_central.append(ep_loss_avg)
    
    # Evaluation
    eval_loss = 0
    correct = 0
    model.eval()
    with torch.no_grad():
        for xs, ys in testloader:
            xs, ys = xs.to(device), ys.to(device)
            outputs = model(xs)
            loss = criterion(outputs, ys)
            eval_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            preds = preds.view(-1)
            correct += torch.sum(torch.eq(preds, ys)).item()
    eval_loss_avg = eval_loss / len(testloader)
    eval_losses_central.append(eval_loss_avg)
    eval_acc = correct / len(test_dataset)
    eval_acc_central.append(eval_acc)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
_, axs = plt.subplots(nrows=1, ncols=3, sharex=True)
axs[0].plot(train_losses_central, label='Training Loss', c='orange')
axs[0].legend()
axs[1].plot(eval_losses_central, label='Test Loss', c='green')
axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[2].plot(eval_acc_central, label='Test Accuracy', c='red')
axs[2].legend()
plt.show()

# %%
def train(model, loader, epochs):
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    losses = []

    model.train()
    for ep in range(epochs):
        ep_losses = []
        for xs, ys in loader:
            xs, ys = xs.to(device), ys.to(device)
            model.zero_grad()
            outputs = model(xs)
            loss = criterion(outputs, ys)
            loss.backward()
            optimizer.step()
            ep_losses.append(loss.item())
        ep_loss_avg = sum(ep_losses) / len(ep_losses)
        losses.append(ep_loss_avg)
    return model.state_dict(), losses

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], float(len(w)))
    return w_avg

# %%
class Client():
    def __init__(self, dataset, net):
        super().__init__()
        self.dataset = dataset
        self.model_instance = net # Net

    def forward(self, x):
        return self.model_instance(x)
        
    def overwrite(self, global_weight):
        w = self.model_instance.state_dict()
        w_avg = copy.deepcopy(global_weight[0])
        for key in w_avg.keys():
            for i in range(1, len(w)):
                w_avg[key] += global_weight[key]
            w_avg[key] = torch.div(w_avg[key], float(len(w+1)))
        return w_avg

# %%
# 100 clients of IID local datasets
num_models = 100

x_idxs = np.arange(len(train_dataset))
ys = train_dataset.targets.numpy().copy()

trainloaders = []
for i in tqdm(range(num_models)):
    x_idxs, x_splits, ys, _ = train_test_split(x_idxs, ys, test_size=1 / num_models, shuffle=True, stratify=ys)
    sampler = SubsetRandomSampler(x_splits)
    trainloaders.append(DataLoader(train_dataset, batch_size=batch_size, sampler=sampler))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
fed_model = Net().to(device)
fed_weights = fed_model.state_dict()

# %%
rounds = 100
epochs = 10

train_losses_fed = []
eval_losses_fed = []
eval_acc_fed = []

for r in tqdm(range(rounds)):
    local_weights = []
    local_losses = []
    if (r + 1) % 10 == 0:
        sys.stdout.write(f'\n | Global Training Round : {r + 1:>2d} / {rounds} |\n')
    
    fed_model.train()
    
    client_idxs = sorted(np.random.randint(0, num_models, 10))
    for i, tr in enumerate(trainloaders):
        if i in client_idxs:
            w, ls = train(copy.deepcopy(fed_model), tr, epochs)
            local_weights.append(copy.deepcopy(w))
            train_losses_fed.append(ls)
            if (r + 1) % 10 == 0:
                sys.stdout.write('  |-- [Client {:>2}] Average Train Loss: {:.4f} ... {} local epochs\n'.format(i + 1, sum(ls) / len(ls), epochs))
            
    fed_weights = average_weights(local_weights)
    fed_model.load_state_dict(fed_weights)

    # Evaluation
    eval_loss = 0
    correct = 0
    fed_model.eval()
    with torch.no_grad():
        for xs, ys in testloader:
            xs, ys = xs.to(device), ys.to(device)
            outputs = fed_model(xs)
            loss = criterion(outputs, ys)
            eval_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            preds = preds.view(-1)
            correct += torch.sum(torch.eq(preds, ys)).item()
    eval_loss_avg = eval_loss / len(testloader)
    eval_losses_fed.append(eval_loss_avg)
    eval_acc = correct / len(test_dataset)
    eval_acc_fed.append(eval_acc)
    if (r + 1) % 10 == 0:
        sys.stdout.write(f'    |---- Test Loss: {eval_loss_avg:.4f}\n')
        sys.stdout.write(f'    |---- Test Accuracy: {100 * eval_acc:.4f}%\n')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global Training Round : 10 / 100 |
#   |-- [Client 12] Average Train Loss: 2.2345 ... 10 local epochs
#   |-- [Client 19] Average Train Loss: 2.2384 ... 10 local epochs
#   |-- [Client 33] Average Train Loss: 2.2371 ... 10 local epochs
#   |-- [Client 35] Average Train Loss: 2.2359 ... 10 local epochs
#   |-- [Client 38] Average Train Loss: 2.2395 ... 10 local epochs
#   |-- [Client 39] Average Train Loss: 2.2366 ... 10 local epochs
#   |-- [Client 48] Average Train Loss: 2.2370 ... 10 local epochs
#   |-- [Client 53] Average Train Loss: 2.2386 ... 10 local epochs
#   |-- [Client 71] Average Train Loss: 2.2351 ... 10 local epochs
#     |---- Test Loss: 2.2274
#     |---- Test Accuracy: 45.2400%
#
#  | Global Training Round : 20 / 100 |
#   |-- [Client  3] Average Train Loss: 1.0208 ... 10 local epochs
#   |-- [Client 15] Average Train Loss: 1.0443 ... 10 local epochs
#   |-- [Client 17] Average Train Loss: 1.0139 ... 10 local epochs
#   |-- [Client 28] Average Train Loss: 1.0287 ... 10 local epochs
#   |-- [Client 34] Average Train Loss: 1.0630 ... 10 local epochs
#   |-- [Client 41] Average Train Loss: 1.0296 ... 10 local epochs
#   |-- [Client 48] Average Train Loss: 1.0526 ... 10 local epochs
#   |-- [Client 58] Average Train Loss: 1.1250 ... 10 local epochs
#   |-- [Client 86] Average Train Loss: 1.0855 ... 10 local epochs
#   |-- [Client 97] Average Train Loss: 1.1601 ... 10 local epochs
#     |---- Test Loss: 0.9188
#     |---- Test Accuracy: 80.6900%
#
#  | Global Training Round : 30 / 100 |
#   |-- [Client 28] Average Train Loss: 0.3948 ... 10 local epochs
#   |-- [Client 30] Average Train Loss: 0.4658 ... 10 local epochs
#   |-- [Client 40] Average Train Loss: 0.3834 ... 10 local epochs
#   |-- [Client 42] Average Train Loss: 0.4315 ... 10 local epochs
#   |-- [Client 52] Average Train Loss: 0.4088 ... 10 local epochs
#   |-- [Client 79] Average Train Loss: 0.9392 ... 10 local epochs
#   |-- [Client 86] Average Train Loss: 0.3985 ... 10 local epochs
#   |-- [Client 89] Average Train Loss: 0.4400 ... 10 local epochs
#   |-- [Client 90] Average Train Loss: 0.4055 ... 10 local epochs
#     |---- Test Loss: 0.4192
#     |---- Test Accuracy: 87.8100%
#
#  | Global Training Round : 40 / 100 |
#   |-- [Client  2] Average Train Loss: 0.3620 ... 10 local epochs
#   |-- [Client  9] Average Train Loss: 0.3995 ... 10 local epochs
#   |-- [Client 55] Average Train Loss: 0.3423 ... 10 local epochs
#   |-- [Client 70] Average Train Loss: 0.3179 ... 10 local epochs
#   |-- [Client 74] Average Train Loss: 0.3834 ... 10 local epochs
#   |-- [Client 81] Average Train Loss: 0.3063 ... 10 local epochs
#   |-- [Client 84] Average Train Loss: 0.9940 ... 10 local epochs
#   |-- [Client 85] Average Train Loss: 1.2353 ... 10 local epochs
#   |-- [Client 94] Average Train Loss: 0.3646 ... 10 local epochs
#     |---- Test Loss: 0.3783
#     |---- Test Accuracy: 88.6200%
#
#  | Global Training Round : 50 / 100 |
#   |-- [Client  9] Average Train Loss: 0.3582 ... 10 local epochs
#   |-- [Client 20] Average Train Loss: 0.3119 ... 10 local epochs
#   |-- [Client 27] Average Train Loss: 0.3520 ... 10 local epochs
#   |-- [Client 37] Average Train Loss: 0.3165 ... 10 local epochs
#   |-- [Client 41] Average Train Loss: 0.3149 ... 10 local epochs
#   |-- [Client 42] Average Train Loss: 0.3131 ... 10 local epochs
#   |-- [Client 60] Average Train Loss: 0.3613 ... 10 local epochs
#   |-- [Client 62] Average Train Loss: 0.2940 ... 10 local epochs
#   |-- [Client 65] Average Train Loss: 0.3197 ... 10 local epochs
#     |---- Test Loss: 0.3151
#     |---- Test Accuracy: 90.6400%
#
#  | Global Training Round : 60 / 100 |
#   |-- [Client 14] Average Train Loss: 0.3241 ... 10 local epochs
#   |-- [Client 15] Average Train Loss: 0.3785 ... 10 local epochs
#   |-- [Client 17] Average Train Loss: 0.2518 ... 10 local epochs
#   |-- [Client 47] Average Train Loss: 0.3202 ... 10 local epochs
#   |-- [Client 54] Average Train Loss: 0.3937 ... 10 local epochs
#   |-- [Client 60] Average Train Loss: 0.3184 ... 10 local epochs
#   |-- [Client 66] Average Train Loss: 0.2454 ... 10 local epochs
#   |-- [Client 74] Average Train Loss: 0.3114 ... 10 local epochs
#   |-- [Client 85] Average Train Loss: 0.4423 ... 10 local epochs
#   |-- [Client 96] Average Train Loss: 0.2886 ... 10 local epochs
#     |---- Test Loss: 0.3348
#     |---- Test Accuracy: 90.3600%
#
#  | Global Training Round : 70 / 100 |
#   |-- [Client  1] Average Train Loss: 0.2554 ... 10 local epochs
#   |-- [Client 15] Average Train Loss: 0.3747 ... 10 local epochs
#   |-- [Client 20] Average Train Loss: 0.2431 ... 10 local epochs
#   |-- [Client 27] Average Train Loss: 0.2989 ... 10 local epochs
#   |-- [Client 38] Average Train Loss: 0.2653 ... 10 local epochs
#   |-- [Client 44] Average Train Loss: 0.2248 ... 10 local epochs
#   |-- [Client 55] Average Train Loss: 0.2445 ... 10 local epochs
#   |-- [Client 58] Average Train Loss: 0.3399 ... 10 local epochs
#   |-- [Client 78] Average Train Loss: 0.3015 ... 10 local epochs
#   |-- [Client 95] Average Train Loss: 0.2091 ... 10 local epochs
#     |---- Test Loss: 0.2713
#     |---- Test Accuracy: 91.8800%
#
#  | Global Training Round : 80 / 100 |
#   |-- [Client 14] Average Train Loss: 0.3472 ... 10 local epochs
#   |-- [Client 28] Average Train Loss: 0.2093 ... 10 local epochs
#   |-- [Client 31] Average Train Loss: 0.2439 ... 10 local epochs
#   |-- [Client 36] Average Train Loss: 0.2333 ... 10 local epochs
#   |-- [Client 37] Average Train Loss: 0.2285 ... 10 local epochs
#   |-- [Client 44] Average Train Loss: 0.1968 ... 10 local epochs
#   |-- [Client 49] Average Train Loss: 0.2451 ... 10 local epochs
#   |-- [Client 91] Average Train Loss: 0.1804 ... 10 local epochs
#   |-- [Client 93] Average Train Loss: 0.2545 ... 10 local epochs
#     |---- Test Loss: 0.2441
#     |---- Test Accuracy: 92.5900%
#
#  | Global Training Round : 90 / 100 |
#   |-- [Client  9] Average Train Loss: 0.2551 ... 10 local epochs
#   |-- [Client 18] Average Train Loss: 0.2302 ... 10 local epochs
#   |-- [Client 36] Average Train Loss: 0.2177 ... 10 local epochs
#   |-- [Client 43] Average Train Loss: 0.1826 ... 10 local epochs
#   |-- [Client 44] Average Train Loss: 0.1768 ... 10 local epochs
#   |-- [Client 68] Average Train Loss: 0.1869 ... 10 local epochs
#   |-- [Client 73] Average Train Loss: 0.2671 ... 10 local epochs
#   |-- [Client 78] Average Train Loss: 0.2545 ... 10 local epochs
#   |-- [Client 98] Average Train Loss: 0.1815 ... 10 local epochs
#   |-- [Client 99] Average Train Loss: 0.2030 ... 10 local epochs
#     |---- Test Loss: 0.2307
#     |---- Test Accuracy: 93.1400%
#
#  | Global Training Round : 100 / 100 |
#   |-- [Client 10] Average Train Loss: 0.2149 ... 10 local epochs
#   |-- [Client 17] Average Train Loss: 0.1846 ... 10 local epochs
#   |-- [Client 21] Average Train Loss: 0.1987 ... 10 local epochs
#   |-- [Client 22] Average Train Loss: 0.2252 ... 10 local epochs
#   |-- [Client 35] Average Train Loss: 0.1996 ... 10 local epochs
#   |-- [Client 51] Average Train Loss: 0.1352 ... 10 local epochs
#   |-- [Client 62] Average Train Loss: 0.1843 ... 10 local epochs
#   |-- [Client 69] Average Train Loss: 0.2316 ... 10 local epochs
#   |-- [Client 81] Average Train Loss: 0.1730 ... 10 local epochs
#   |-- [Client 91] Average Train Loss: 0.1443 ... 10 local epochs
#     |---- Test Loss: 0.2153
#     |---- Test Accuracy: 93.3300%

# %%
_, axs = plt.subplots(nrows=1, ncols=2, sharex=True)
axs[0].plot(eval_losses_central, label='Central', c='green')
axs[0].plot(eval_losses_fed, label='Federated', c='red')
axs[0].legend()
axs[0].set_title('Test Loss')
axs[1].plot(eval_acc_central, label='Central', c='green')
axs[1].plot(eval_acc_fed, label='Federated', c='red')
axs[1].legend()
axs[1].set_title('Test Accuracy')
plt.show()
